# %%
import numpy as np
arr = np.array([[-1, 2, 0, 4], [4,-0.5, 6, 0], [2.6, 0, 7, 8], [3, -7, 4, 2.0]])
print("Original array:\n", arr)
# Out:
# Original array:
#  [[-1.   2.   0.   4. ]
#  [ 4.  -0.5  6.   0. ]
#  [ 2.6  0.   7.   8. ]
#  [ 3.  -7.   4.   2. ]]

# %%
a=np.array ([1,2,3,4,5,6,7])
print ("\n Original array: \n", a)
print("\n Return every other elemnents from the entier array:", arr[::2])
# Out:
#  Original array:
#  [1 2 3 4 5 6 7]
#
#  Return every other elemnents from the entier array: [[-1.   2.   0.   4. ]
#  [ 2.6  0.   7.   8. ]]

# %%
print(arr[0:3:2])
# Out:
# [[-1.   2.   0.   4. ]
#  [ 2.6  0.   7.   8. ]]

# %%
import numpy as np
arr = np.array([[-1, 2, 0, 4], [4,-0.5, 6, 0], [2.6, 0, 7, 8], [3, -7, 4, 2.0]])
temp=arr[:2,:3]
print(temp)
# Out:
# [[-1.   2.   0. ]
#  [ 4.  -0.5  6. ]]

# %%
#integer array indexing
temp=arr[[0,1,2,3], [3, 2, 1,0]]
print("\nElements at indices (0,3), (1,2), (2,1),""(3,0):\n", temp)
# Out:
# Elements at indices (0,3), (1,2), (2,1),(3,0):
#  [4. 6. 0. 3.]

# %%
#boolean array indexing
cond=arr>2
#cond is a boolean array
temp=arr[cond]
print("Elements greater than 2:\n", temp)
# Out:
# Elements greater than 2:
#  [4.  4.  6.  2.6 7.  8.  3.  4. ]

# %%
#joining two array
arr1=np.array([1,2,3])
arr2=np.array([4,5,6,])
arr=np.concatenate((arr1,arr2))
print("OG arr:",arr1,arr2)
print("JOINT ARR:",arr)
# Out:
# OG arr: [1 2 3] [4 5 6]
# JOINT ARR: [1 2 3 4 5 6]
